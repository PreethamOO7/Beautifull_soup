# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib
import urllib.request
import csv

# %%
with open('Links.csv','w') as newFile:
    newFileWriter = csv.writer(newFile)
    newFileWriter.writerow(['user_id','Links'])
    newFileWriter.writerow([1,'xyz'])
    newFileWriter.writerow([2,'pqr'])

# %%
url="https://www.amazon.in/Mens-Tshirts-Polos/b?ie=UTF8&node=1968120031&ref_=nav_shopall_sbc_mfashion_tshirts"
page=urllib.request.urlopen(url)
soup = BeautifulSoup(page,"html.parser")

# %%
for img in soup.findAll('img'):
    temp=img.get('src')
    
    print(temp)
# Out:
# https://images-na.ssl-images-amazon.com/images/G/31/gno/sprites/nav-sprite-global_bluebeacon-V3-1x_optimized._CB468962293_.png
# https://images-eu.ssl-images-amazon.com/images/G/31/x-locale/common/transparent-pixel._CB386942716_.gif
# https://images-eu.ssl-images-amazon.com/images/G/31/IMG17/Fashion/January/Ingresses/Subnav/Amazon-fashion-logo._CB534243057_.png
# https://images-eu.ssl-images-amazon.com/images/G/31/img17/Fashion/150-x-50._CB515077405_.jpg
# https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel._CB386942464_.gif
# https://images-eu.ssl-images-amazon.com/images/I/918VVN1YlUL._SL150_.jpg
# https://images-eu.ssl-images-amazon.com/images/I/81WMctksAOL._SL150_.jpg
# https://images-eu.ssl-images-amazon.com/images/I/71lo1Apr1tL._SL150_.jpg
# https://images-eu.ssl-images-amazon.com/images/G/31/acs/ux/transparent.png
# https://images-eu.ssl-images-amazon.com/images/G/31/acs/ux/transparent.png
# ...

# %%
with open('Links.csv', 'wb') as csvfile:
    filewriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    filewriter.writerow
